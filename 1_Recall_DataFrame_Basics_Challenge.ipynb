# %% [markdown]
# <a href="https://colab.research.google.com/github/omo22nde/gz-dbt-repository/blob/omo22nde-patch-1/1_Recall_DataFrame_Basics_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Recall DataFrame Basics

# %% [markdown]
# Execute the following cell

# %%
import pandas as pd

df = pd.DataFrame({"A": [1, 2, 3, 4, 5, 6],
                   "B": [7, 8, 9, 10, 11, 12],
                   "C": [13, 14, 15, 16, 17, 18],
                   "D": ["a", "a", "a", "b", "b", "b"],
                   "E": ["c", "d", "c", "d", "c", "d"]})
df
# Out:
#    A   B   C  D  E
# 0  1   7  13  a  c
# 1  2   8  14  a  d
# 2  3   9  15  a  c
# 3  4  10  16  b  d
# 4  5  11  17  b  c
# 5  6  12  18  b  d

# %% [markdown]
# ## DataFrame attributes

# %% [markdown]
# Display `df` columns and index names

# %% [markdown]
# ## Play with DataFrame columns

# %% [markdown]
# Put column B in a variable `df_B`. What is the type of this variable?

# %%
df_B = df[["B"]]

# %%
type(df_B)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Does the following code change anything? Why?
#
#
# `df_B = df[["B"]]`

# %%
df_B = df["B"]

# %% [markdown]
# Create a column F filled with 12

# %%
df_B = df["B"]

# %%
df['F'] =12

# %% [markdown]
# Create a DataFrame `df_E_B` containing columns B and E. We want column E to be **before** column B.

# %%
df_E_B = df.loc[:, ['E', 'B']]

# %%
df_E_B
# Out:
#    E   B
# 0  c   7
# 1  d   8
# 2  c   9
# 3  d  10
# 4  c  11
# 5  d  12

# %% [markdown]
# ## Filter a DataFrame

# %% [markdown]
# Display rows 1 to 3 and columns B, C, D from `df` DataFrame.

# %%
df.loc[1:3, ['B','C','D']]
# Out:
#     B   C  D
# 1   8  14  a
# 2   9  15  a
# 3  10  16  b

# %% [markdown]
# Why does this line of code cause an error?

# %%
df.iloc[1:4, 1:4]
# Out:
#     B   C  D
# 1   8  14  a
# 2   9  15  a
# 3  10  16  b

# %% [markdown]
# > **Your Answer Here (Double click)**

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# Select rows from `df` where the value in column B is greater than or equal to 8.

# %%
df[df['B'] >= 8]
# Out:
#    A   B   C  D  E   F
# 1  2   8  14  a  d  12
# 2  3   9  15  a  c  12
# 3  4  10  16  b  d  12
# 4  5  11  17  b  c  12
# 5  6  12  18  b  d  12

# %% [markdown]
# Select rows from df where the value in column B is greater than or equal to 8 and the value in column D is equal to "a".

# %%
df[(df['B'] >= 8) & (df['D'] == 'a')]
# Out:
#    A  B   C  D  E   F
# 1  2  8  14  a  d  12
# 2  3  9  15  a  c  12

# %% [markdown]
# What does this line of code do?

# %% [markdown]
# ## Operations on DataFrame columns

# %% [markdown]
# Calculate the average of columns A, B and F **by using the pd.DataFrame() [inbuilt function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html).**

# %%
df[["A","B","F"]].mean()
# Out:
# A     3.5
# B     9.5
# F    12.0
# dtype: float64

# %% [markdown]
# What happens if we repeat the previous instruction but pass **axis=1** as parameter to `.mean()`function?

# %%
df[["A","B","F"]].mean(axis=1)
# Out:
# 0     6.666667
# 1     7.333333
# 2     8.000000
# 3     8.666667
# 4     9.333333
# 5    10.000000
# dtype: float64
